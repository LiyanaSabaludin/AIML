# %%
#example to generate a dataset

import numpy as np

a = np.arange(0,10000)
b = np.arange(0,10000)
c = np.arange(0,10000)
d = np.arange(0,10000)

# %%
a = np.random.randint(500,1000,(5000)) #start , end , size
b = np.random.randint(500,1000,(5000))
c = np.random.randint(500,1000,(5000))
d = np.random.randint(500,1000,(5000))
e = np.random.randint(500,1000,(5000))
f = np.random.randint(500,1000,(5000))

# %%
import pandas as pd

population = {
    'KL': a,
    'J.B': b,
    'Melaka': c,
    'N.Sembilan': d,
    'Perak': e,
    'Terengganu': f
}
df = pd.DataFrame(population)

df.tail()
# Out:
#        KL  J.B  Melaka  N.Sembilan  Perak  Terengganu
# 4995  874  893     994         813    928         720
# 4996  950  831     856         869    753         665
# 4997  572  910     912         868    934         617
# 4998  544  500     537         907    607         589
# 4999  786  744     910         848    894         916

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KL          5000 non-null   int32
#  1   J.B         5000 non-null   int32
#  2   Melaka      5000 non-null   int32
#  3   N.Sembilan  5000 non-null   int32
#  4   Perak       5000 non-null   int32
#  5   Terengganu  5000 non-null   int32
# dtypes: int32(6)
# memory usage: 117.3 KB
#        KL  J.B  Melaka  N.Sembilan  Perak  Terengganu
# 0     730  646     578         872    587         909
# 1     930  526     976         554    827         656
# 2     934  964     887         693    947         774
# 3     624  638     522         955    518         833
# 4     708  715     897         927    759         747
# ...   ...  ...     ...         ...    ...         ...
# 4995  874  893     994         813    928         720
# 4996  950  831     856         869    753         665
# ...

# %%
df = pd.read_csv("mental_health_dataset.csv")   
df
# Out:
#      Student_ID  Age  Gender   GPA  Stress_Level  Anxiety_Score  \
# 0             1   23   Other  2.52             5             20
# 1             2   19    Male  2.74             5              3
# 2             3   21  Female  3.53             5             11
# 3             4   18    Male  2.04             4             15
# 4             5   19   Other  2.87             1              2
# ..          ...  ...     ...   ...           ...            ...
# 495         496   20   Other  3.34             4              0
# 496         497   18  Female  3.22             2              7
# 497         498   23   Other  2.86             4             17
# 498         499   18  Female  2.45             4             14
# 499         500   18   Other  3.52             1              0
#
#      Depression_Score                                  Daily_Reflections  \
# 0                   6  Onto foreign do environmental anyone every nea...
# ...

# %%
df.shape
# Out:
# (500, 13)

# %%
df = pd.read_csv("Amazon.csv")   
df
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1      ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2      ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3      ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4      ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
# ...           ...         ...         ...            ...       ...
# 99995  ORD0099996  2023-03-07  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  2021-11-24  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  2023-04-29  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  2021-11-01  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  2021-12-04  CUST029492   Sunita Reddy    P00019
#
#                ProductName           Category       Brand  Quantity  \
# 0               Drone Mini              Books   BrightLux         3
# ...
