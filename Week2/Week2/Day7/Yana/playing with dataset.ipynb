# %%
import numpy as np
import pandas as pd

print(np.__version__)
print(pd.__version__)
# Out:
# 2.3.5
# 2.3.3

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Remove species (target) column if you want just features
iris_without_Species = iris_df.copy()  # or drop columns if needed

# Now calculate sepal area
sepalarea = iris_without_Species['sepal length (cm)'] * iris_without_Species['sepal width (cm)']
print(sepalarea.head())
# Out:
# 0    17.85
# 1    14.70
# 2    15.04
# 3    14.26
# 4    18.00
# dtype: float64

# %%
species2 = pd.DataFrame({
    'SepalLength': [5.1, 4.9, 4.7],
    'SepalWidth': [3.5, 3.0, 3.2],
    'PetalLength': [1.4, 1.4, 1.3],
    'PetalWidth': [0.2, 0.2, 0.2],
    'Species': ['setosa', 'setosa', 'setosa']
})

# Now you can use .head()
print(species2.head())
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa

# %%
species2.head()
type(species2)
# Out:
# pandas.core.frame.DataFrame

# %%
sepal_area = iris_without_Species['sepal length (cm)'] * iris_without_Species['sepal width (cm)']
print(sepal_area.head())
# Out:
# 0    17.85
# 1    14.70
# 2    15.04
# 3    14.26
# 4    18.00
# dtype: float64

# %%
iris_without_Species['sepal_area'] = sepalarea
iris_without_Species.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    sepal_area
# 0       17.85
# 1       14.70
# 2       15.04
# 3       14.26
# 4       18.00

# %%
petal_area = iris_without_Species['petal length (cm)'] * iris_without_Species['petal width (cm)']
print(petal_area.head())
# Out:
# 0    0.28
# 1    0.28
# 2    0.26
# 3    0.30
# 4    0.28
# dtype: float64

# %%
iris_without_Species['petal_area'] = petal_area
iris_without_Species.head(50)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# ...

# %%
filtered = iris_without_Species[iris_without_Species['sepal_area'] > 14]

print(filtered)

# %%
largeFlowers = iris_without_Species[(iris_without_Species['sepal_area'] > 15) ]
largeFlowers.head(10)
#largeFlowers.info()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# 11                4.8               3.4                1.6               0.2
# 14                5.8               4.0                1.2               0.2
#
#     sepal_area  petal_area
# 0        17.85        0.28
# 2        15.04        0.26
# 4        18.00        0.28
# ...

# %%
large_flowers_count = (iris_without_Species['sepal_area'] > 14).sum()
print(large_flowers_count)
# Out:
# 133

# %%
largeFlowers = iris_without_Species[iris_without_Species['sepal_area'] == 16]
largeFlowers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 35 to 35
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  1 non-null      float64
#  1   sepal width (cm)   1 non-null      float64
#  2   petal length (cm)  1 non-null      float64
#  3   petal width (cm)   1 non-null      float64
#  4   sepal_area         1 non-null      float64
#  5   petal_area         1 non-null      float64
# dtypes: float64(6)
# memory usage: 56.0 bytes

# %%
#largeFlowers = iris_without_Species[iris_without_Species['sepal_area'] > 14]

# Now you can sort
sortedLargeFlowers = largeFlowers.sort_values(by='sepal_area', ascending=False)

# Show top 5
largeFlowers=sortedLargeFlowers.head()
largeFlowers
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 131                7.9               3.8                6.4               2.0
#
#      sepal_area  petal_area
# 131       30.02        12.8

# %%
areaoflargestflower= largeFlowers['sepal_area'][131]
areaoflargestflower
# Out:
# np.float64(30.02)

# %%
areaoflargestflower= sortedLargeFlowers['sepal_area'].max()
areaoflargestflower
# Out:
# np.float64(30.02)

# %%
area_of_smallest_flower = iris_without_Species['sepal_area'].min()
print(area_of_smallest_flower)
# Out:
# 10.0

# %%
largeFlowers= sortedLargeFlowers.head(1)
largeFlowers
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 131                7.9               3.8                6.4               2.0
#
#      sepal_area  petal_area
# 131       30.02        12.8
