# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached numpy-2.3.5-cp314-cp314-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.1 MB 5.0 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.1 MB 5.8 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.1 MB 6.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.1 MB 6.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.1 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.1 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 6.7 MB/s  0:00:01
# ...

# %%
import pandas as pd

# %%
#mine
#temperature = pd.Series([30, 32, 28, 29, 31])

#data = {
    "City": ["Kuala Lumpur", "Putrajaya", "Johor Bahru", "Melaka", "N.Sembilan"], 
    "Temperature": [30, 32, 29, 28, 31]}

#df = pd.DataFrame(data)
#print(df)
# Out:
#            City  Temperature
# 0  Kuala Lumpur           30
# 1     Putrajaya           32
# 2   Johor Bahru           29
# 3        Melaka           28
# 4    N.Sembilan           31

# %%
#trainer
#series object mean one dimensional array single column
temp11 = pd.Series([32, 31, 50, 34, -2])
print("type of temp11:",type(temp11))

#dictionary of temperature data
temperatures =  {
    "City": ["KL", "KL", "SG", "NY", "HLS"], 
    "Temperatures": [23, 29, 40, 0, 5]
}
 
 #create a DataFrame object
 #pandas DataFrame is two dimensional array with rows and columns
temp_df = pd.DataFrame(temperatures)
print("type of temp_df:",type(temp_df))

print(temp_df)
print(temp11)
# Out:
# type of temp11: <class 'pandas.core.series.Series'>
# type of temp_df: <class 'pandas.core.frame.DataFrame'>
#   City  Temperatures
# 0   KL            23
# 1   KL            29
# 2   SG            40
# 3   NY             0
# 4  HLS             5
# 0    32
# 1    31
# 2    50
# 3    34
# 4    -2
# dtype: int64

# %%
temp_df['City'] 
temp_df
# Out:
#   City  Temperatures
# 0   KL            23
# 1   KL            29
# 2   SG            40
# 3   NY             0
# 4  HLS             5

# %%
temp_df["City"]
# Out:
# 0     KL
# 1     KL
# 2     SG
# 3     NY
# 4    HLS
# Name: City, dtype: object

# %%
temp_df['temp11'] = temp11
temp_df
# Out:
#   City  Temperatures  temp11
# 0   KL            23      32
# 1   KL            29      31
# 2   SG            40      50
# 3   NY             0      34
# 4  HLS             5      -2

# %%
temp_df["empty_temp"] = {}
temp_df
# Out:
#   City  Temperatures  temp11 empty_temp
# 0   KL            23      32        NaN
# 1   KL            29      31        NaN
# 2   SG            40      50        NaN
# 3   NY             0      34        NaN
# 4  HLS             5      -2        NaN

# %%
temp_df["mel"] = {}
temp_df
# Out:
#   City  Temperatures  temp11 empty_temp  mel
# 0   KL            23      32        NaN  NaN
# 1   KL            29      31        NaN  NaN
# 2   SG            40      50        NaN  NaN
# 3   NY             0      34        NaN  NaN
# 4  HLS             5      -2        NaN  NaN

# %%
temp_df["yanaRating"] = pd.Series([5, 4, 1, -3, 0])
temp_df
# Out:
#   City  Temperatures  temp11 empty_temp  mel  yanaRating
# 0   KL            23      32        NaN  NaN           5
# 1   KL            29      31        NaN  NaN           4
# 2   SG            40      50        NaN  NaN           1
# 3   NY             0      34        NaN  NaN          -3
# 4  HLS             5      -2        NaN  NaN           0

# %%
temp_df["melRating"] = pd.Series([5, 5, 5, 5, 5])
temp_df
# Out:
#   City  Temperatures  temp11 empty_temp  mel  yanaRating  melRating
# 0   KL            23      32        NaN  NaN           5          5
# 1   KL            29      31        NaN  NaN           4          5
# 2   SG            40      50        NaN  NaN           1          5
# 3   NY             0      34        NaN  NaN          -3          5
# 4  HLS             5      -2        NaN  NaN           0          5

# %%
temp_df.to_csv("City Rating without index row number.csv", index=False )

# %%
data = {
    "City": ["KL", "KL", "KL", "MLK", "NS"], 
    "Temperature": [30, 32, 29, 28, 31]}

df = pd.DataFrame(data)
print(df)
# Out:
#   City  Temperature
# 0   KL           30
# 1   KL           32
# 2   KL           29
# 3  MLK           28
# 4   NS           31

# %%
#counting values in a column
#method 1
df["City"].value_counts()
# Out:
# City
# KL     3
# MLK    1
# NS     1
# Name: count, dtype: int64

# %%
#method 2
df["City"].unique()
# Out:
# array(['KL', 'MLK', 'NS'], dtype=object)

# %%
df["City"].duplicated()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# Name: City, dtype: bool

# %%
df2 = df["City"].drop_duplicates(inplace=False)
df2
# Out:
# 0     KL
# 3    MLK
# 4     NS
# Name: City, dtype: object
