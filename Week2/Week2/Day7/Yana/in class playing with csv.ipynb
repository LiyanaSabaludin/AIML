# %%
#let try to bring in the csv file we created earlier

import pandas as pd

df = pd.read_csv("City Rating.csv")
print(df)
# Out:
#    Unnamed: 0 City  Temperatures  temp11  empty_temp  mel  yanaRating  \
# 0           0   KL            23      32         NaN  NaN           5
# 1           1   HK            29      31         NaN  NaN           4
# 2           2   SG            40      50         NaN  NaN           1
# 3           3   NY             0      34         NaN  NaN          -3
# 4           4  HLS             5      -2         NaN  NaN           0
#
#    melRating
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5

# %%
df2 = pd.read_csv("City Rating without index row number.csv")
print(df2)
# Out:
#   City  Temperatures  temp11  empty_temp  mel  yanaRating  melRating
# 0   KL            23      32         NaN  NaN           5          5
# 1   HK            29      31         NaN  NaN           4          5
# 2   SG            40      50         NaN  NaN           1          5
# 3   NY             0      34         NaN  NaN          -3          5
# 4  HLS             5      -2         NaN  NaN           0          5
