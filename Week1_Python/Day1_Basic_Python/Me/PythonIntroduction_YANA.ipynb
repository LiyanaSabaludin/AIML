# %% [markdown]
# **Python** **Introduction**

# %%
print('Welcome to Python')
# Out:
# Welcome to Python

# %%
print('First Example in Python')
# Out:
# First Example in Python

# %%
#input example
username=input('Enter username:')
print('Welcom Mr.\\Ms.:'+ username)
# Out:
# Enter username:Liyana
# Welcom Mr.\Ms.:Liyana

# %%
#input example
username=input('Enter username:')
print('Welcome to Python:' + username)
# Out:
# Enter username:yana
# Welcome to Python:yana

# %%
num1=12
num2=13
result=num1+num2
print(result)
# Out:
# 25

# %%
print(f'First Number {num1} and Second Number {num2} Result: {result}')
# Out:
# First Number 12 and Second Number 13 Result: 25

# %%
fnum=int(input('Enter First Number :'))
snum=int(input('Enter Second Number :'))
result=fnum+snum
print(f'Result aftr adding {fnum} and {snum} is = \t {result}')
# Out:
# Enter First Number :4
# Enter Second Number :4
# Result aftr adding 4 and 4 is = 	 8

# %%
first_name='Yana'
last_name='Sabaludin'
full_name=first_name+' '+last_name
print(full_name)
# Out:
# Yana Sabaludin

# %%
type(first_name)
# Out:
# str

# %%
num=12
type(num)
print(f'Type of fnum {type(fnum)} and snum {type(snum)}')
# Out:
# Type of fnum <class 'int'> and snum <class 'int'>

# %%
my_num=12.44
type(my_num)
# Out:
# float

# %%
fnum=float(input('Enter First Number : \t'))
snum=float(input('Enter Second Number : \t'))
result=fnum+snum
print(f'Result aftr adding {fnum} and {snum} is = \t {result}')
# Out:
# Enter First Number : 	34.876
# Enter Second Number : 	45.908
# Result aftr adding 34.876 and 45.908 is = 	 80.78399999999999

# %%
#Boolean or boll
is_active=True
type(is_active)
# Out:
# bool

# %%
is_active=False
type(is_active)
# Out:
# bool

# %%
print('Is Active User?',is_active)
# Out:
# Is Active User? False

# %%
print(f'Is Active User?',is_active)
# Out:
# Is Active User? False

# %%
#Binary Values
byte_ex=b'Hello'
type(byte_ex)

byte_Array=bytearray(b'Hello')
type(byte_Array)
#
mv=memoryview(byte_Array)
type(mv)
# Out:
# memoryview

# %%
#complex type
complex_num=2+3j
print(complex_num)
type(complex_num)
# Out:
# (2+3j)
# complex

# %%
#Squence Type
#list []
list_ex=[10,20,30,40,50]
print(list_ex)
type(list_ex)
# Out:
# [10, 20, 30, 40, 50]
# list

# %%
cars=['Toyota','Perodua', 'BMW','Tesla']
print(cars)
type(cars)
# Out:
# ['Toyota', 'Perodua', 'BMW', 'Tesla']
# list

# %%
#Tuple
tuple_ex=(10,20,30,40,50)
print(tuple_ex)
type(tuple_ex)
# Out:
# (10, 20, 30, 40, 50)
# tuple

# %%
#Set
set_ex=(10,20,30,40,50)
print(set_ex)
type(set_ex)
# Out:
# (10, 20, 30, 40, 50)
# tuple

# %%
#range
range_ex=range(10)
print(range_ex)
type(range_ex)
# Out:
# range(0, 10)
# range

# %%
range_ex2=range(5)
print(range_ex2)
type(range_ex2)
# Out:
# range(0, 5)
# range

# %%
#Dictionary
emp={
    "id":1,
    "name":"Sam",
    "salary":20000.78
}
print(emp)
type(emp)
# Out:
# {'id': 1, 'name': 'Sam', 'salary': 20000.78}
# dict
