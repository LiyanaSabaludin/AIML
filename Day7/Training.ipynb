# %%
class welcome:
    def __init__(self, name):
        self.name = name

    def welcome(self, new_name):
        return f"Welcome {new_name}!!!"

# %%
obj = welcome("Liyana")
print(obj.welcome("Liyana"))
# Out:
# Welcome Liyana!!!
